# %% [markdown]
# <a target="_blank" href="https://colab.research.google.com/github/LuisAngelMendozaVelasco/Applied_Data_Science_with_Python_Specialization/blob/main/Applied_Plotting-Charting_and_Data_Representation_in_Python/Week3/Labs/Matplotlib_3D.ipynb"><img src="https://www.tensorflow.org/images/colab_logo_32px.png" />Run in Google Colab</a>

# %%
# %%bash
# # If running in Google Colab
#
# # mkdir data
# # wget https://raw.githubusercontent.com/LuisAngelMendozaVelasco/Applied_Data_Science_with_Python_Specialization/main/Applied_Plotting-Charting_and_Data_Representation_in_Python/Week3/Labs/data/iris.csv -P ./data

# %%
import pandas as pd
import numpy as np
from mpl_toolkits.mplot3d import axes3d
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style("whitegrid")
# %matplotlib notebook

# %%
iris = pd.read_csv('./data/iris.csv')
iris.head()
# Out:
#    SepalLength  SepalWidth  PetalLength  PetalWidth         Name
# 0          5.1         3.5          1.4         0.2  Iris-setosa
# 1          4.9         3.0          1.4         0.2  Iris-setosa
# 2          4.7         3.2          1.3         0.2  Iris-setosa
# 3          4.6         3.1          1.5         0.2  Iris-setosa
# 4          5.0         3.6          1.4         0.2  Iris-setosa

# %%
plt.figure()

for species, irissubset in iris.groupby('Name'):
    plt.scatter(irissubset['PetalLength'], irissubset['PetalWidth'], alpha=0.8, label=species)

plt.xlabel('PetalLength')
plt.ylabel('PetalWidth')
plt.legend()
plt.show()

# %%
fig = plt.figure(figsize=(8, 8))
ax = fig.add_subplot(111, projection='3d')

for species, irissubset in iris.groupby('Name'):
    ax.scatter(irissubset['SepalLength'], irissubset['PetalLength'], irissubset['PetalWidth'], label=species)
    
ax.set_xlabel('Sepal Length')
ax.set_ylabel('Petal Length')
ax.set_zlabel('Petal Width')
ax.legend(loc=2)
plt.show()

# %%
x, y, z = axes3d.get_test_data(0.1)

fig = plt.figure(figsize=(8, 8))
ax = fig.add_subplot(111, projection='3d')
ax.plot_wireframe(x, y, z)
plt.show()

# %%
fig = plt.figure(figsize=(8, 8))
ax = fig.add_subplot(111, projection='3d')
ax.plot_surface(x, y, z, cmap='viridis')
plt.show()

# %%
fig = plt.figure()
ax = fig.add_subplot(111)
x, y, z = axes3d.get_test_data(0.1)
ax.contourf(x, y, z, 100, cmap='viridis')
plt.show()

# %%
from matplotlib import animation
# %matplotlib widget

fig = plt.figure(figsize=(8, 8))
ax = fig.add_subplot(111, projection='3d')
surface = ax.plot_surface(x, y, z, cmap='viridis')

def animate(i):
    ax.view_init(elev=0, azim=i)
    return fig

anim = animation.FuncAnimation(fig, animate, frames=360, interval=10, blit=True)
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
